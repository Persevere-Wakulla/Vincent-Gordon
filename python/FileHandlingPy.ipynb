# %% [markdown]
# File Handling:
#         In a large software app where they process a large number of data, we cannot expect that data to be stored in a variable.
#
#         Files are written with data and stored permanently. Using Python we will handle these files in our Apps.

# %% [markdown]
# Types of File in Python:
#
#             There a re 2 types of files in Python and each of them are explained below in detail with examples for your easy understanding.
#
#             Binary File
#             Text File
#
#             Binary Files: In Python - Most of the files that we see in our computer system are called binary files.
#                 Document Files: .pdf,.doc,.xls etc
#                 Image Files: .png,.jpg,.gif,.bmp etc
#                 Video Files: .mp4,.3gp,.mkv,.avi etc
#                 Audio Files: .mp3,.wav,.mka,.aac etc
#                 Database Files: .mdb,.accde,.frm,.sqlite etc
#                 Archive Files: .zip,.rat,.iso,.7z etc
#                 Executable Files: .exe,.dll,.class etc
#
#             All Binary files follow a specific format. We can open some binary files in the normal text editor but we can't read the content present inside the file. Thats because all the binary files will be encoded in the binary format.
#
#                     For handling such binary files we need a specific type of software to open it.
#
#             Text Files dont have any specific encoding and it can be opened in normal text editor itself.
#
#                 Web Standards: html,CSS,XML,JSON, etc
#                 Source Code: c,app,js,py,java, etc
#                 Documents: txt,tex,RTF, etc
#                 Tabular Data: csv,tsv, etc
#                 Configuration: ini,cfg,reg, etc
#
#             Python File Handling Operations:
#
#                 Most importantly there are 4 types of operations that ca be handled by Python on Files
#
#                 Open
#                 Read
#                 Write
#                 Close
#
#             Other operations Include:
#
#                 Rename
#                 Delete

# %% [markdown]
# Create and Open a File:
#
#         Syntax:
#                 file_object = open(file_name, 'mode')
#
#         The mode in the open function syntax will tell Python what operation we want to do on the file.
#
#         For text file:
#             'r' - Read Mode: Read mode is used only to read data from the file.
#             'w' - Write Mode: This mode is used when you want to write data into the file or modify it. Remember write mode overwrites the present data in the file.
#             'a' - Append Mode: Append mode is used to append data to the file. Remember data will be appended at the end of the file pointer.
#             'r+' - Read or Write Mode: This mode is used when we want to write or read the data from the same file.
#
#         Note: The above mentioned modes are for opening reading or writing text files only.
#
#         While using Binary files. we have to use the same modes with the letter 'b' at the end. So that Python can understand that we are interacting with binary files.
#                 'wb' - Open a file for write only mode in the binary format.
#                 'rb' - Open a file for the read-only mode in the binary format.
#                 'ab' - Open a file for appending only mode in the binary format.
#                 'rb+' - Open a file for the read and write only mode in the binary format.
#                 'ab+' - Open a file for appending and read-only mode in the binary format.
#
#         Example 1: open a  text file in read-write mode.

# %%
fo = open('../../../three.js3d.odt', 'r+')

# %%
fo
# Out:
# <_io.TextIOWrapper name='../../../three.js3d.odt' mode='r+' encoding='utf-8'>

# %%
fb = open('../../Responsive Web Design/Imagez/1000cc-go-kart.jpg' ,'rb+')

# %%
fb
# Out:
# <_io.BufferedRandom name='../../Responsive Web Design/Imagez/1000cc-go-kart.jpg'>

# %% [markdown]
# Read From File:
#
#         In order to read a file in python, we must open the file in read mode.
#
#         There are 3 ways in which we can read the files in Python.
#
#             read([n])
#             readline([n])
#             readlines()
#
#         Here, n is the number of bytes to be read.
#
#     Example 3

# %%
my_file = open ('./README.md','r')
print (my_file.read(50))
# Out:
# # 🐍python
#
#
#
# ## Getting started
#
# To make it easy f

# %%
print(my_file.read())
# Out:
# or you to get started with GitLab, here's a list of recommended next steps.
#
# Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!
#
# ## Add your files
#
# - [ ] [Create](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#create-a-file) or [upload](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#upload-a-file) files
# - [ ] [Add files using the command line](https://docs.gitlab.com/ee/gitlab-basics/add-file.html#add-a-file-using-the-command-line) or push an existing Git repository with the following command:
#
# ```
# cd existing_repo
# git remote add origin http://gitlab.wakulla.perseverenow.org/vgordon/python.git
# git branch -M main
# git push -uf origin main
# ```
#
# ## Integrate with your tools
#
# - [ ] [Set up project integrations](http://gitlab.wakulla.perseverenow.org/vgordon/python/-/settings/integrations)
#
# ## Collaborate with your team
#
# ...

# %%
my_file = open ('./README.md','r')

print(my_file.read(5))
# Out:
# # 🐍py

# %%
print (my_file.read())
# Out:
# thon
#
#
#
# ## Getting started
#
# To make it easy for you to get started with GitLab, here's a list of recommended next steps.
#
# Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!
#
# ## Add your files
#
# - [ ] [Create](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#create-a-file) or [upload](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#upload-a-file) files
# - [ ] [Add files using the command line](https://docs.gitlab.com/ee/gitlab-basics/add-file.html#add-a-file-using-the-command-line) or push an existing Git repository with the following command:
#
# ```
# cd existing_repo
# git remote add origin http://gitlab.wakulla.perseverenow.org/vgordon/python.git
# git branch -M main
# git push -uf origin main
# ```
#
# ## Integrate with your tools
#
# ...

# %%
my_file = open ('./README.md','r')

print(my_file.read())
# Out:
# # 🐍python
#
#
#
# ## Getting started
#
# To make it easy for you to get started with GitLab, here's a list of recommended next steps.
#
# Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!
#
# ## Add your files
#
# - [ ] [Create](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#create-a-file) or [upload](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#upload-a-file) files
# - [ ] [Add files using the command line](https://docs.gitlab.com/ee/gitlab-basics/add-file.html#add-a-file-using-the-command-line) or push an existing Git repository with the following command:
#
# ```
# cd existing_repo
# git remote add origin http://gitlab.wakulla.perseverenow.org/vgordon/python.git
# git branch -M main
# git push -uf origin main
# ```
#
# ## Integrate with your tools
#
# ...

# %% [markdown]
# Example 4:

# %%
my_file = open ('./README.md','r')

print(my_file.readline())
# Out:
# # 🐍python

# %%
print(my_file.readline())

# %%
print(my_file.readline())

# %%
print(my_file.readline())

# %%
print(my_file.readline())
# Out:
# ## Getting started

# %%
print(my_file.readline())

# %%
print(my_file.readline())
# Out:
# To make it easy for you to get started with GitLab, here's a list of recommended next steps.

# %%
print(my_file.readline(6))

# %%
print(my_file.readline())
# Out:
# Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!

# %%
print(my_file.readline(6))

# %%
print(my_file.readline(6))
# Out:
# ## Add

# %% [markdown]
# Reads line by line

# %%
my_file = open('./README.md', 'r')

for line in my_file:
    print(line)
# Out:
# # 🐍python
#
#
#
#
#
#
#
# ## Getting started
#
#
#
# To make it easy for you to get started with GitLab, here's a list of recommended next steps.
#
#
#
# Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!
#
#
#
# ## Add your files
#
#
#
# - [ ] [Create](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#create-a-file) or [upload](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#upload-a-file) files
#
# - [ ] [Add files using the command line](https://docs.gitlab.com/ee/gitlab-basics/add-file.html#add-a-file-using-the-command-line) or push an existing Git repository with the following command:
#
#
#
# ```
#
# cd existing_repo
#
# git remote add origin http://gitlab.wakulla.perseverenow.org/vgordon/python.git
#
# git branch -M main
#
# git push -uf origin main
#
# ```
#
#
#
# ## Integrate with your tools
#
#
#
# ...

# %% [markdown]
# Example 5: Reading a specific line from a file

# %%
line_number = 20

my_file = open('./README.md' ,'r')

currentline = 1

for line in my_file:
    if (currentline == line_number):
        print (line)
        break
    
    currentline =currentline + 1
# Out:
# git push -uf origin main

# %% [markdown]
# Example 6:

# %%
with open ('./README.md' ,'r') as f:
    lines = [line.rstrip() for line in f]
print(lines)
# Out:
# ['# 🐍python', '', '', '', '## Getting started', '', "To make it easy for you to get started with GitLab, here's a list of recommended next steps.", '', 'Already a pro? Just edit this README.md and make it your own. Want to make it easy? [Use the template at the bottom](#editing-this-readme)!', '', '## Add your files', '', '- [ ] [Create](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#create-a-file) or [upload](https://docs.gitlab.com/ee/user/project/repository/web_editor.html#upload-a-file) files', '- [ ] [Add files using the command line](https://docs.gitlab.com/ee/gitlab-basics/add-file.html#add-a-file-using-the-command-line) or push an existing Git repository with the following command:', '', '```', 'cd existing_repo', 'git remote add origin http://gitlab.wakulla.perseverenow.org/vgordon/python.git', 'git branch -M main', 'git push -uf origin main', '```', '', '## Integrate with your tools', '', '- [ ] [Set up project integrations](http://gitlab.wakulla.perseve
# ...

# %% [markdown]
# Image File Handling:

# %%
from PIL import Image,ImageDraw,ImageFont
from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
location1 = r'./Images/TcDivision.jpg'
location2 = r'./Images/xbox.png'

# %%
im1 = Image.open(location1)
im2 = Image.open(location2)

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500>

# %% [markdown]
# Properties of the Image:
#                 The format attribute identifies the source of an image. If the image was not read from a file, it is set to none
#
#                 The size attribute is a 2-tuple containing width and height (in pixels).
#
#                 The mode attribute defines the number and names of the bands in the image and also the pixel type and depth Common modes are:
#
#                         'L' (luminance) for greyscale images.
#                         'RGB' for true color images.
#                         'CMYK' for pre press images.

# %%
im1.format, im1.size,im1.mode
# Out:
# ('JPEG', (375, 500), 'RGB')

# %%
im2.format, im2.size, im2.mode
# Out:
# ('PNG', (77, 77), 'RGBA')

# %% [markdown]
# Displaying Images:

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
plt.imshow(im1)

plt.subplot(122)
plt.imshow(im2)

# %%
display(im1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x500>

# %% [markdown]
# Saving an Image:

# %%
im1.save('Div.jpg')

# %% [markdown]
# Cropping:
#         box = (100,100,400,400)
#         region = im1.crop(box)
#
#         The region is defined by a 4-tuple, Where coordinates are (left, upper, right, lower).
#
#         The Python imaging Library uses a coordinate system with (0,0) in the upper left corner.
#
#         Also note that coordinates refer to positions between the pixels, so the region in the above example is exactly 300 x 300 pixels.

# %%
box = (150,20,300,500)
region = im1.crop(box)

# %%
plt.imshow(region)

# %% [markdown]
# Copy an Image:

# %%
im1_copy = im1.copy()
plt.imshow(im1_copy)

# %% [markdown]
# Transposing An Image:

# %%
out = im1.transpose(Image.FLIP_LEFT_RIGHT)
out = im1.transpose(Image.FLIP_TOP_BOTTOM)
out = im1.transpose(Image.ROTATE_90)
out = im1.transpose(Image.ROTATE_180)
out = im1.transpose(Image.ROTATE_270)
plt.imshow(out)
